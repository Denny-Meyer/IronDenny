# %%
import pandas as pd
import numpy as np

# %%
ls Data -al
# Out:
# total 368
# drwxrwxr-x 2 meyd meyd  4096 Okt 25 12:23 ./
# drwxrwxr-x 3 meyd meyd  4096 Okt 25 12:25 ../
# -rw-rw-r-- 1 meyd meyd  6148 Okt 25 12:23 .DS_Store
# -rw-rw-r-- 1 meyd meyd 88951 Okt 25 12:23 file1.xlsx
# -rw-rw-r-- 1 meyd meyd 86543 Okt 25 12:23 file2.xlsx
# -rw-rw-r-- 1 meyd meyd 85752 Okt 25 12:23 file3.xlsx
# -rw-rw-r-- 1 meyd meyd 87809 Okt 25 12:23 file4.xlsx
# -rw-rw-r-- 1 meyd meyd   154 Okt 25 12:23 vlookup_table.csv

# %%
file1 = pd.read_excel('Data/file1.xlsx')
file2 = pd.read_excel('Data/file2.xlsx')
file3 = pd.read_excel('Data/file3.xlsx')
file4 = pd.read_excel('Data/file4.xlsx')

# %%
hk_df = pd.concat([file1, file2, file2, file3, file4])

# %%
hk_df.columns = [item.lower() for item in hk_df.columns]

# %%
hk_df
# Out:
#       controln state gender      hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M      537  365  473.0     0  19387      1     89
# 2        43333    FL      F      725  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F      995  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1001     41537    FL      F      742  396  470.0     0  15356      7     37
# 1002      4881    FL      M      599  100  423.0     4  11670     10     27
# 1003     66358    ND      M      593  258  299.0     0  10186      1     70
# 1004      2231    WI   male      564  217  397.0     0  12315      0     96
# 1005     68534    MI      M      651  431  505.0     0  14845      7     77
#
#         ic2  ic3    avggift
# ...

# %%
hk_df.rename(columns= 
{
    'controln':'id',
    'hv1': 'median_home_val',
    'ic1':'median_houshold_income',
    'ic2': 'med_fam_income'
})
# Out:
#           id state gender median_home_val  median_houshold_income    ic4  \
# 0      44060    FL      M          AAA896                     392  520.0
# 1      96093    IL      M             537                     365  473.0
# 2      43333    FL      F             725                     301  436.0
# 3      21885    NC      M         AAA1095                     401  413.0
# 4     190108    FL      F             995                     252  348.0
# ...      ...   ...    ...             ...                     ...    ...
# 1001   41537    FL      F             742                     396  470.0
# 1002    4881    FL      M             599                     100  423.0
# 1003   66358    ND      M             593                     258  299.0
# 1004    2231    WI   male             564                     217  397.0
# 1005   68534    MI      M             651                     431  505.0
#
#       hvp1    ic5  pobc1  pobc2  med_fam_income  ic3    avggift
# ...

# %%
#pd.read_csv('Data/vlookup_table.csv')
