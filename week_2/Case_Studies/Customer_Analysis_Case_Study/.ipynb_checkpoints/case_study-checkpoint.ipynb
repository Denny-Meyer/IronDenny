# %% [markdown]
# # Activites List
#
# Here are some of the tasks you need to perform:
#
# ### Activity 1
#
# - [x] Aggregate data into one Data Frame using Pandas.
# - [x] Standardizing header names
# - [ ] Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data
# - [ ] Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of complaints )
# - [x] Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns
# - [ ] Removing duplicates
# - [ ] Replacing null values – Replace missing values with means of the column (for numerical columns)

# %%
# setup libraries
import pandas as pd
import numpy as np

# %%
# read files
file_1 = pd.read_csv('Data/file1.csv')
file_2 = pd.read_csv('Data/file2.csv')
file_3 = pd.read_csv('Data/file3.csv')

# %%
# combine data
data = pd.concat([file_1, file_2, file_3]).reindex()
#data.columns

# put GENDER values to Gender and ST to State

data['Gender'] = list(map(lambda x, y: x if x == x else y, data['Gender'],data['GENDER']))
data['State'] = list(map(lambda x, y: x if x == x else y, data['State'], data['ST']))

# drop GENDER and ST as it is double information
data.drop(columns=['ST','GENDER'], inplace=True)

# %%
data
# Out:
#      Customer             Education Customer Lifetime Value   Income  \
# 0     RB50392                Master                     NaN      0.0
# 1     QZ44356              Bachelor              697953.59%      0.0
# 2     AI49188              Bachelor             1288743.17%  48767.0
# 3     WW63253              Bachelor              764586.18%      0.0
# 4     GA49547  High School or Below              536307.65%  36357.0
# ...       ...                   ...                     ...      ...
# 7065  LA72316              Bachelor             23405.98798  71941.0
# 7066  PK87824               College             3096.511217  21604.0
# 7067  TD14365              Bachelor             8163.890428      0.0
# 7068  UP19263               College             7524.442436  21941.0
# 7069  Y167826               College             2611.836866      0.0
#
#       Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 7065                  73.0                         0   Personal Auto
# 7066                  79.0                         0  Corporate Auto
# 7067                  85.0                         3  Corporate Auto
# 7068                  96.0                         0   Personal Auto
# 7069                  77.0                         0  Corporate Auto
#
#       Vehicle Class  Total Claim Amount       State Gender
# 0     Four-Door Car            2.704934  Washington    NaN
# 1     Four-Door Car         1131.464935     Arizona      F
# 2      Two-Door Car          566.472247      Nevada      F
# 3               SUV          529.881344  California      M
# 4     Four-Door Car           17.269323  Washington      M
# ...             ...                 ...         ...    ...
# 7065  Four-Door Car          198.234764  California      M
# 7066  Four-Door Car          379.200000  California      F
# 7067  Four-Door Car          790.784983  California      M
# 7068  Four-Door Car          691.200000  California      M
# 7069   Two-Door Car          369.600000  California      M
#
# [12074 rows x 11 columns]

# %%
# clean up gender
data['Gender'].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
F = ['Femal', 'female', 'F']
M = ['Male', 'M']
data['Gender'] = list(map(lambda x: 'M' if x==x and x in M else ('F' if x==x and x in F else x), data['Gender']))
data['Gender'].unique()
# Out:
# array([nan, 'F', 'M'], dtype=object)

# %%
# fix State values
data['State'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
data['State'] = list(map(lambda x: x if x != 'AZ' else 'Arizona', data['State']))
data['State'] = list(map(lambda x: x if x != 'Cali' else 'California', data['State']))
data['State'] = list(map(lambda x: x if x != 'WA' else 'Washington', data['State']))

# %%
data['State'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', nan],
#       dtype=object)

# %%
#data['Customer Lifetime Value'].describe

#remove percent value and cast to float
data['Customer Lifetime Value'] = list(map(lambda x: float(str(x).strip('%\r\t\n')) if x==x else float(0), data['Customer Lifetime Value']))
# convert to float

#debug print(data['Customer Lifetime Value'])

#data['Customer Lifetime Value'] = 
data['Customer Lifetime Value'].astype('float64')

# round 
data['Customer Lifetime Value'] = data['Customer Lifetime Value'].round(0)

print(data.dtypes)
#debug print(data['Customer Lifetime Value'])
data
# Out:
# Customer                      object
# Education                     object
# Customer Lifetime Value      float64
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# State                         object
# Gender                        object
# dtype: object
#      Customer             Education  Customer Lifetime Value   Income  \
# 0     RB50392                Master                      0.0      0.0
# 1     QZ44356              Bachelor                 697954.0      0.0
# 2     AI49188              Bachelor                1288743.0  48767.0
# 3     WW63253              Bachelor                 764586.0      0.0
# 4     GA49547  High School or Below                 536308.0  36357.0
# ...       ...                   ...                      ...      ...
# 7065  LA72316              Bachelor                  23406.0  71941.0
# 7066  PK87824               College                   3097.0  21604.0
# 7067  TD14365              Bachelor                   8164.0      0.0
# 7068  UP19263               College                   7524.0  21941.0
# 7069  Y167826               College                   2612.0      0.0
#
#       Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 7065                  73.0                         0   Personal Auto
# 7066                  79.0                         0  Corporate Auto
# 7067                  85.0                         3  Corporate Auto
# 7068                  96.0                         0   Personal Auto
# 7069                  77.0                         0  Corporate Auto
#
#       Vehicle Class  Total Claim Amount       State Gender
# 0     Four-Door Car            2.704934  Washington    NaN
# 1     Four-Door Car         1131.464935     Arizona      F
# 2      Two-Door Car          566.472247      Nevada      F
# 3               SUV          529.881344  California      M
# 4     Four-Door Car           17.269323  Washington      M
# ...             ...                 ...         ...    ...
# 7065  Four-Door Car          198.234764  California      M
# 7066  Four-Door Car          379.200000  California      F
# 7067  Four-Door Car          790.784983  California      M
# 7068  Four-Door Car          691.200000  California      M
# 7069   Two-Door Car          369.600000  California      M
#
# [12074 rows x 11 columns]

# %%
# format number of open complains
# looks like one format is just the number 0-5 and second format is 1/0-5/00 eg. 1/2/00
# remove 1/ and /00 from string

# first fill fields with 0 which are NaN
data.loc[data['Number of Open Complaints'].isnull()] = 0
#data['Number of Open Complaints'].fillna(0)
data['Number of Open Complaints'] = list(map(lambda x: int(x[2]) if x==x and str(x).startswith('1/') and str(x).endswith('/00') else int(x), data['Number of Open Complaints']))

data['Number of Open Complaints'].astype(int)
data['Number of Open Complaints'].unique()
# Out:
# array([0, 2, 1, 3, 5, 4])

# %%
# fix education
data['Education'].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College',
#        'Bachelors', 'Doctor', 0], dtype=object)

# %%
# replace 'Bachelors' with 'Bachelor'
data['Education'] = list(map(lambda x: x if x != 'Bachelors' else 'Bachelor', data['Education']))

data['Education'].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College', 'Doctor',
#        0], dtype=object)

# %%
# as it looks, all fields without filled education are as well without any kind of data
# time to clean this up
data = data[data.Education != 0]

# %%
data
# Out:
#      Customer             Education  Customer Lifetime Value   Income  \
# 0     RB50392                Master                      0.0      0.0
# 1     QZ44356              Bachelor                 697954.0      0.0
# 2     AI49188              Bachelor                1288743.0  48767.0
# 3     WW63253              Bachelor                 764586.0      0.0
# 4     GA49547  High School or Below                 536308.0  36357.0
# ...       ...                   ...                      ...      ...
# 7065  LA72316              Bachelor                  23406.0  71941.0
# 7066  PK87824               College                   3097.0  21604.0
# 7067  TD14365              Bachelor                   8164.0      0.0
# 7068  UP19263               College                   7524.0  21941.0
# 7069  Y167826               College                   2612.0      0.0
#
#       Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# 0                   1000.0                          0   Personal Auto
# 1                     94.0                          0   Personal Auto
# 2                    108.0                          0   Personal Auto
# 3                    106.0                          0  Corporate Auto
# 4                     68.0                          0   Personal Auto
# ...                    ...                        ...             ...
# 7065                  73.0                          0   Personal Auto
# 7066                  79.0                          0  Corporate Auto
# 7067                  85.0                          3  Corporate Auto
# 7068                  96.0                          0   Personal Auto
# 7069                  77.0                          0  Corporate Auto
#
#       Vehicle Class  Total Claim Amount       State Gender
# 0     Four-Door Car            2.704934  Washington    NaN
# 1     Four-Door Car         1131.464935     Arizona      F
# 2      Two-Door Car          566.472247      Nevada      F
# 3               SUV          529.881344  California      M
# 4     Four-Door Car           17.269323  Washington      M
# ...             ...                 ...         ...    ...
# 7065  Four-Door Car          198.234764  California      M
# 7066  Four-Door Car          379.200000  California      F
# 7067  Four-Door Car          790.784983  California      M
# 7068  Four-Door Car          691.200000  California      M
# 7069   Two-Door Car          369.600000  California      M
#
# [9137 rows x 11 columns]

# %%
data['Education'].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College', 'Doctor'],
#       dtype=object)

# %%
#drop 2937 rows

#data.drop(data.loc[data['Education']==0].index, inplace=True)

# reset and remove duplicates
#data.reset_index()
#data.drop_duplicates(inplace= True)

#data.reset_index()
#data.duplicated().unique()

# %%
data.drop_duplicates()
#non_gender = data.loc[(data['Gender'] != 'M') & (data['Gender'] != 'F')]
#data.drop(non_gender, inplace=True)
#non_gender
#data.reset_index(inplace=True, drop=True)
data.reset_index(inplace= True, drop= True)
data
# Out:
#      Customer             Education  Customer Lifetime Value   Income  \
# 0     RB50392                Master                      0.0      0.0
# 1     QZ44356              Bachelor                 697954.0      0.0
# 2     AI49188              Bachelor                1288743.0  48767.0
# 3     WW63253              Bachelor                 764586.0      0.0
# 4     GA49547  High School or Below                 536308.0  36357.0
# ...       ...                   ...                      ...      ...
# 9132  LA72316              Bachelor                  23406.0  71941.0
# 9133  PK87824               College                   3097.0  21604.0
# 9134  TD14365              Bachelor                   8164.0      0.0
# 9135  UP19263               College                   7524.0  21941.0
# 9136  Y167826               College                   2612.0      0.0
#
#       Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# 0                   1000.0                          0   Personal Auto
# 1                     94.0                          0   Personal Auto
# 2                    108.0                          0   Personal Auto
# 3                    106.0                          0  Corporate Auto
# 4                     68.0                          0   Personal Auto
# ...                    ...                        ...             ...
# 9132                  73.0                          0   Personal Auto
# 9133                  79.0                          0  Corporate Auto
# 9134                  85.0                          3  Corporate Auto
# 9135                  96.0                          0   Personal Auto
# 9136                  77.0                          0  Corporate Auto
#
#       Vehicle Class  Total Claim Amount       State Gender
# 0     Four-Door Car            2.704934  Washington    NaN
# 1     Four-Door Car         1131.464935     Arizona      F
# 2      Two-Door Car          566.472247      Nevada      F
# 3               SUV          529.881344  California      M
# 4     Four-Door Car           17.269323  Washington      M
# ...             ...                 ...         ...    ...
# 9132  Four-Door Car          198.234764  California      M
# 9133  Four-Door Car          379.200000  California      F
# 9134  Four-Door Car          790.784983  California      M
# 9135  Four-Door Car          691.200000  California      M
# 9136   Two-Door Car          369.600000  California      M
#
# [9137 rows x 11 columns]

# %% [markdown]
# ### Activity 2
#
# - Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central
# - Standardizing the data – Use string functions to standardize the text data (lower case)

# %%
col = data.dtypes

# %%
# Out:
# [dtype('O'), dtype('O'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('int64'), dtype('O'), dtype('O'), dtype('float64'), dtype('O'), dtype('O')]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/58/83__n5jj77s0p9pv81ccxck40000gn/T/ipykernel_12798/3923848868.py in <module>
#       1 print(list(col))
#       2 for i in range(len(col)):
# ----> 3     if data.loc[i:] == pd.dtypes('O'):
#       4         print("j")
#
# /opt/anaconda3/envs/DA_Enviroment/lib/python3.9/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'dtypes'

# %%
cat_zone = {
    'west region' : 'california',
    'north west'  : 'oregon',
    'east'        : 'washington',
    'central'     :['arizona', 'nevada']
}

# %%
def regroup_location(state: str) -> str:
    for k,v in cat_zone.items():
        if state in v:
            return k
    return state

# %%
data['State'].str.lower()
# Out:
# 0       washington
# 1          arizona
# 2           nevada
# 3       california
# 4       washington
#            ...
# 9132    california
# 9133    california
# 9134    california
# 9135    california
# 9136    california
# Name: State, Length: 9137, dtype: object

# %%
print(regroup_location('california'))
print(regroup_location('nevada'))
# Out:
# west region
# central
# <map object at 0x7fe4d124dbb0>
# <map object at 0x7fe4d124d970>

# %% [markdown]
# ### Activity 3
#
# - Which columns are numerical?
# - Which columns are categorical?
# - Check and deal with NaN values. (Hint:Replacing null values – Replace missing values with means of the column (for numerical columns)).
# - Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.
